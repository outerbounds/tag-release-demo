# %%
from metaflow import Flow, namespace
from metaflow.cards import get_cards

# %%
namespace('production:oleg2-mztdpcvj_scheduledtree-0-cpvz')
# Out:
# 'production:oleg2-mztdpcvj_scheduledtree-0-cpvz'

# %%
list(Flow('ScheduledTree'))
# Out:
# [Run('ScheduledTree/sfn-0f6dd86d-28e7-bdfa-10ca-a829ec5f0247_79671951-9ee9-2899-811a-0bd0f901c273'),
#  Run('ScheduledTree/sfn-bd09cefd-0ef8-8f00-1ee3-44b233a91256_2de4cb4b-08de-50e2-ec80-4194e669d5a0'),
#  Run('ScheduledTree/sfn-618b6b86-2640-fb4e-1fa0-81b5e7b6f06e_780c0035-7e95-47f7-f35a-248fe98ff06e'),
#  Run('ScheduledTree/sfn-f5d21842-84a5-566f-f094-bfea307cfa96_6db43fd3-80b5-96ed-4338-d9c22b0e277e'),
#  Run('ScheduledTree/sfn-62f8ae7e-b179-5de5-1725-261b86285936_70be0cbc-1255-7fa3-4bdd-4a9b86b6e8ad'),
#  Run('ScheduledTree/sfn-6362161a-7a87-ce5e-bc9a-f0ce64f66340_d88ec303-015e-7b22-28da-0538e9db363d'),
#  Run('ScheduledTree/sfn-133dfbe6-e07e-9b55-72cd-39e98b542cc0_abdc50be-46bb-0704-5fb2-6affd1caa1a9')]

# %%
run = Flow('ScheduledTree').latest_successful_run
run
# Out:
# Run('ScheduledTree/sfn-0f6dd86d-28e7-bdfa-10ca-a829ec5f0247_79671951-9ee9-2899-811a-0bd0f901c273')

# %%
run.data.accuracy
# Out:
# 0.8435374149659864

# %%
get_cards(run.end_task)
# Out:
# <h1>Displaying Card Of Type : Default</h1>
# <script type='text/javascript'>var mfContainerId = '2482fadd-2cad-48e4-ace9-af3d67244df8';</script>
# <div class='embed' data-container='2482fadd-2cad-48e4-ace9-af3d67244df8'><!DOCTYPE html>
# <html lang="en">
#
# <head>
#   <meta charset="utf-8" />
#   <meta name="viewport" content="width=device-width,initial-scale=1" />
#   <link
#       rel="shortcut icon"
#       href="data:image/png;base64,..."
#     />
#   <title>ScheduledTree/sfn-0f6dd86d-28e7-bdfa-10ca-a829ec5f0247_79671951-9ee9-2899-811a-0bd0f901c273/end/a8cc38bb-3134-4aee-bd57-56d29fd9f8df</title>
#   <style>
#     .container.svelte-teyund{width:100%;display:flex;flex-direction:column;position:relative}/* PrismJS 1.25.0
# https://prismjs.com/download.html#themes=prism&languages=clike+python */
# ...

# %%
run.add_tag('production')
